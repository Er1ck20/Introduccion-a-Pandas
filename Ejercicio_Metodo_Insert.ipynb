# %%
import numpy as np
import pandas as pd

df = pd.read_csv('StudentsPerformance.csv')

# %%
x = np.random.randint(1, 5, size=10)
serie = pd.Series(x, index=np.arange(0, 10))

# %%
df.insert(1, 'Ejemplo', serie)

# %%
df.head(20)
# Out:
#     gender  Ejemplo race/ethnicity parental level of education         lunch  \
# 0   female      4.0        group B           bachelor's degree      standard
# 1   female      1.0        group C                some college      standard
# 2   female      4.0        group B             master's degree      standard
# 3     male      3.0        group A          associate's degree  free/reduced
# 4     male      4.0        group C                some college      standard
# 5   female      2.0        group B          associate's degree      standard
# 6   female      4.0        group B                some college      standard
# 7     male      4.0        group B                some college  free/reduced
# 8     male      2.0        group D                 high school  free/reduced
# 9   female      3.0        group B                 high school  free/reduced
# 10    male      NaN        group C          associate's degree      standard
# 11    male      NaN        group D          associate's degree      standard
# 12  female      NaN        group B                 high school      standard
# 13    male      NaN        group A                some college      standard
# 14  female      NaN        group A             master's degree      standard
# 15  female      NaN        group C            some high school      standard
# 16    male      NaN        group C                 high school      standard
# 17  female      NaN        group B            some high school  free/reduced
# 18    male      NaN        group C             master's degree  free/reduced
# 19  female      NaN        group C          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                     none          72             72             74
# 1                completed          69             90             88
# 2                     none          90             95             93
# 3                     none          47             57             44
# 4                     none          76             78             75
# 5                     none          71             83             78
# 6                completed          88             95             92
# 7                     none          40             43             39
# 8                completed          64             64             67
# 9                     none          38             60             50
# 10                    none          58             54             52
# 11                    none          40             52             43
# 12                    none          65             81             73
# 13               completed          78             72             70
# 14                    none          50             53             58
# 15                    none          69             75             78
# 16                    none          88             89             86
# 17                    none          18             32             28
# 18               completed          46             42             46
# 19                    none          54             58             61

# %%
import pandas as pd

# %%
# Listas
month = [5, 12, 2, 1]
year = [2014, 2011, 2009, 2022]
sale = [54, 78, 48, 32]

# %%
# Almacenamos las listas en un diccionario
d_df = {'Meses': month, 
        'Año': year, 
        'Rebaja':sale}

# %%
# Creamos el df
df = pd.DataFrame(d_df)

# %%
df
# Out:
#    Meses   Año  Rebaja
# 0      5  2014      54
# 1     12  2011      78
# 2      2  2009      48
# 3      1  2022      32

# %%
df.set_index('Meses', inplace=True)

# %%
df
# Out:
#         Año  Rebaja
# Meses
# 5      2014      54
# 12     2011      78
# 2      2009      48
# 1      2022      32

# %%
df.sort_index()
# Out:
#         Año  Rebaja
# Meses
# 1      2022      32
# 2      2009      48
# 5      2014      54
# 12     2011      78
