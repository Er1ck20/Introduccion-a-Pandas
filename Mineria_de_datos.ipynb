# %% [markdown]
# # Visualizando los datos desde jupyter

# %%
# Importamos
import pandas as pd

# %%
# Leyendo el archivo excel
df = pd.read_excel('EQUIPOS.xlsx')

# %%
# Mostrando el archivo excel
df
# Out:
#    Unnamed: 0        Unnamed: 1 Unnamed: 2  Unnamed: 3      Unnamed: 4  \
# 0         NaN               NaN        NaN         NaN             NaN
# 1       MARCA            MODELO  CATEGORIA         RAM  ALMACENAMIENTO
# 2      Lenovo         Ideapad 3          A   8 GB DDR4      256 GB SSD
# 3          HP     EliteBook 820          B   8 GB DDR4      300 GB HDD
# 4        Asus       TUF Dash 15         A+  16 GB DDR5      512 GB SSD
# 5          HP        ChromeBook          A   4 GB DDR4       64 GB HDD
# 6        Asus     Swift x SFX14         A+  16 GB DDR5      512 GB SSD
# 7        Acer        ChromeBook          A   4 GB DDR4       32 GB SSD
# 8          HP    PC portatil 17          A   4 GB DDR4      256 GB SSD
# 9       APPLE      MacBook Pro          A+  16 GB DDR5      512 GB SSD
# 10      APPLE       MacBook Air          A   8 GB DDR4      512 GB SSD
# 11       Acer  Aspire 5 A515-56          A   4 GB DDR4      256 GB SSD
# ...

# %%
df.head(5)
# Out:
#   Unnamed: 0     Unnamed: 1 Unnamed: 2  Unnamed: 3      Unnamed: 4  \
# 0        NaN            NaN        NaN         NaN             NaN
# 1      MARCA         MODELO  CATEGORIA         RAM  ALMACENAMIENTO
# 2     Lenovo      Ideapad 3          A   8 GB DDR4      256 GB SSD
# 3         HP  EliteBook 820          B   8 GB DDR4      300 GB HDD
# 4       Asus    TUF Dash 15         A+  16 GB DDR5      512 GB SSD
#
#              Unnamed: 5 Unnamed: 6
# 0                   NaN        NaN
# 1            PROCESADOR     PRECIO
# 2    i3-11va Generacion      22187
# 3   i5 - 6ta Generacion      13499
# 4  i7 - 12va Generacion      59500
